# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sendo_products.csv')
df.tail(20)
# Out:
#      productID                                        productName  \
# 100   86975837         Bàn phím Keyboard T-WOLF T16 Led 7 màu USB
# 101   86992263  Bàn phím Keyboard HP GK-200 TKL Chính hãng (Ph...
# 102   86992230  Bàn phím Keyboard iMICE MK-X80 USB Chính hãng ...
# 103   86992132  Bàn phím Keyboard SIMETECH G8 Gaming (Giả cơ, ...
# 104  102677205  Bàn phím Laptop Dell Inspiron 15-3000, 3541, 3...
# 105  107811839  Bàn phím chơi game cơ học Logitech G813 RGB LI...
# 106   86962855       Bàn phím Keyboard NEWMEN E340 USB Chính hãng
# 107   86958307     Bàn phím Keyboard T-WOLF TF-20 Led 7 màu (USB)
# 108   86992405  Bàn phím Keyboard NEWMEN GM320 Chính hãng (Phí...
# 109   69883218             Bàn Phím Cơ Dây Gaming Led Rapoo V500L
# 110  116245761                              Bàn Phím Số RAPOO K10
# 111  108783362  Bàn phím Keyboard T-WOLF T80 Black/White/Pink ...
# 112  109669015  Bao da bàn phím Logitech Combo Touch for Ipad ...
# ...

# %%
df.columns
# Out:
# Index(['productID', 'productName', 'productURL', 'productImage',
#        'productRating', 'productNumRate', 'productNumSold', 'productBrand',
#        'categoryID', 'categoryInfo', 'productOrgPrice', 'productCrtPrice',
#        'sellerID', 'sellerName', 'sellerURL', 'sellerRating', 'sellerType',
#        'sellerLocation', 'inventoryStatus', 'inventoryStock', 'promotion'],
#       dtype='object')
